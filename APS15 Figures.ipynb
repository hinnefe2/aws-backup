# %%
# %matplotlib inline

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rcParams['lines.linewidth'] = 3

# %%
V_bg_up = np.linspace(-1.0,1.0,1000)

def smearedStepFn(x, x0, kT):
    return 1 - 1 / (np.exp((x-x0)/kT) + 1)

def carriers(V_eff):
    return abs(V_eff) + 0.01

def V_eff(V_bg,offsets):
    return V_bg + sum(offsets)

def V_dipole(V_bg, sweep_up):
    dip_offset = -1    # starting value of dipole effect (on/off changes by +1.0)
    dip_switch = 0.5     # applied backgate that causes dipoles to switch (+/- symmetric)
    dip_strength = 0.5   # size of dipole gating effect
    dip_sharpness = 0.1  # sharpness of dipole transition
    dip_step_up = True   # whether the dipole function is a step up or step down, viewed left to right
    sign = 2*(-0.5 + int(dip_step_up)) # +1 for dip_step_up==True, -1 for False
    
    if sweep_up:
        return dip_strength * (dip_offset + smearedStepFn(sign*V_bg, sign*dip_switch, dip_sharpness))
    else:
        return dip_strength * (dip_offset + smearedStepFn(sign*V_bg, -sign*dip_switch, dip_sharpness))

def conductance(V_bg, dip_fraction, offsetsA, offsetsB, sweep_up = True):
    q_e = 1
    geometry_factor = 1
    mu = 1000
    rho1 = 1 / (q_e * mu * carriers(V_eff(V_bg, offsetsA)))
    rho2 = 1 / (q_e * mu * carriers(V_eff(V_bg, offsetsB)))
    R1 = rho1 * geometry_factor
    R2 = rho2 * geometry_factor
    return 1 / (dip_fraction*R2 + (1-dip_fraction)*R1)

# %%
# plot 1

v_ext = 0.25
v_dip = -0.5

colors = ['b','g','r','black'] #sns.color_palette()
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,5), sharex=True);

ax1.set_xlim([-1.1,1.1]);
ax1.set_title('Total Gate Voltage')
ax1.set_xlabel('Applied V_gate (V)')
ax1.set_ylabel('Effective Gate Voltage')
ax1.plot(V_bg_up, [0]*1000, '--', color='grey', label='Dirac point')

ax2.set_title('Conductance vs Applied Gate Voltage')
ax2.set_xlabel('Applied V_gate (V)')
ax2.set_ylabel('Conductance')
ax2.set_ylim([0,1400]);

# next two lines = just applied gate
ax1.plot(V_bg_up, V_bg_up, color=colors[0], alpha=1, label='applied backgate');
ax2.plot(V_bg_up, [conductance(v,0, [0],[0]) for v in V_bg_up],color=colors[0])

# next two lines = applied gate + extrinsic doping
#ax1.plot(V_bg_up, [v_ext]*1000, color=colors[1], alpha=1, label='extrinsic doping')
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext],[0]) for v in V_bg_up],color=colors[1])

# next two lines = applied gate + extrinsic doping + dipole doping
#ax1.plot(V_bg_up, [v_dip]*1000, color=colors[2], alpha=1, label='extrinsic doping')
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext + v_dip],[0]) for v in V_bg_up],color=colors[2])

ax1.legend(loc=2);

plt.savefig('Fig1-1.png', dpi=200, transparent=True, bbox_inches='tight')

# %%
# plot 2

v_ext = 0.25
v_dip = -0.5
colors = ['b','g','r','black'] #sns.color_palette()

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,5), sharex=True);

ax1.set_xlim([-1.1,1.1]);
ax1.set_title('Total Gate Voltage')
ax1.set_xlabel('Applied V_gate (V)')
ax1.set_ylabel('Effective Gate Voltage')
ax1.plot(V_bg_up, [0]*1000, '--', color='grey', label='Dirac point')

ax2.set_title('Conductance vs Applied Gate Voltage')
ax2.set_xlabel('Applied V_gate (V)')
ax2.set_ylabel('Conductance')


# next two lines = just applied gate
ax1.plot(V_bg_up, V_bg_up, color=colors[0], alpha=0.5, label='applied backgate');
ax2.plot(V_bg_up, [conductance(v,0, [0],[0]) for v in V_bg_up],color=colors[0], alpha = 0.5)

# next two lines = applied gate + extrinsic doping
ax1.plot(V_bg_up, [v_ext]*1000, color=colors[1], alpha=1, label='extrinsic doping')
ax2.plot(V_bg_up, [conductance(v,0, [v_ext],[0]) for v in V_bg_up],color=colors[1])

# next two lines = applied gate + extrinsic doping + dipole doping
#ax1.plot(V_bg_up, [v_dip]*1000, color=colors[2], alpha=1, label='extrinsic doping')
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext + v_dip],[0]) for v in V_bg_up],color=colors[2])

ax1.legend(loc=2);

plt.savefig('Fig1-2.png', dpi=200, transparent=True, bbox_inches='tight')

# %%
# plot 3

v_ext = 0.25
v_dip = -0.5

colors = ['b','g','r','black'] #sns.color_palette()
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,5), sharex=True);

ax1.set_xlim([-1.1,1.1]);
ax1.set_title('Total Gate Voltage')
ax1.set_xlabel('Applied V_gate (V)')
ax1.set_ylabel('Effective Gate Voltage')
ax1.plot(V_bg_up, [0]*1000, '--', color='grey', label='Dirac point')

ax2.set_title('Conductance vs Applied Gate Voltage')
ax2.set_xlabel('Applied V_gate (V)')
ax2.set_ylabel('Conductance')


# next two lines = just applied gate
ax1.plot(V_bg_up, V_bg_up, color=colors[0], alpha=0.25, label='applied backgate');
ax2.plot(V_bg_up, [conductance(v,0, [0],[0]) for v in V_bg_up],color=colors[0], alpha=0.25)

# next two lines = applied gate + extrinsic doping
ax1.plot(V_bg_up, [v_ext]*1000, color=colors[1], alpha=0.5, label='extrinsic doping')
ax2.plot(V_bg_up, [conductance(v,0, [v_ext],[0]) for v in V_bg_up],color=colors[1], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping
ax1.plot(V_bg_up, [v_dip]*1000, color=colors[2], alpha=1, label='dipole doping')
ax2.plot(V_bg_up, [conductance(v,0, [v_ext + v_dip],[0]) for v in V_bg_up],color=colors[2])

ax1.legend(loc=2);

plt.savefig('Fig1-3.png', dpi=200, transparent=True, bbox_inches='tight')

# %%
# plot 4

v_ext = 0.25
v_dip = -0.5

colors = ['b','g','r','black'] #sns.color_palette()
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,5), sharex=True);

ax1.set_xlim([-1.1,1.1]);
ax1.set_title('Total Gate Voltage')
ax1.set_xlabel('Applied V_gate (V)')
ax1.set_ylabel('Effective Gate Voltage')
ax1.plot(V_bg_up, [0]*1000, '--', color='grey', label='Dirac point')

ax2.set_title('Conductance vs Applied Gate Voltage')
ax2.set_xlabel('Applied V_gate (V)')
ax2.set_ylabel('Conductance')


# next two lines = just applied gate
ax1.plot(V_bg_up, V_bg_up, color=colors[0], alpha=0.25, label='applied backgate');
ax2.plot(V_bg_up, [conductance(v,0, [0],[0]) for v in V_bg_up],color=colors[0], alpha=0.25)

# next two lines = applied gate + extrinsic doping
ax1.plot(V_bg_up, [v_ext]*1000, color=colors[1], alpha=0.5, label='extrinsic doping')
ax2.plot(V_bg_up, [conductance(v,0, [v_ext],[0]) for v in V_bg_up],color=colors[1], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping
ax1.plot(V_bg_up, [v_dip]*1000, color=colors[2], alpha=0.5, label='dipole doping')
ax2.plot(V_bg_up, [conductance(v,0, [v_ext + v_dip],[0]) for v in V_bg_up],color=colors[2], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping on half chip
ax2.plot(V_bg_up, [conductance(v,0.5, [v_ext + v_dip],[v_ext]) for v in V_bg_up],color=colors[3], label='half with dipole doping\nhalf without')

ax2.legend(loc=1);
ax1.legend(loc=2);

plt.savefig('Fig1-4.png', dpi=200, transparent=True, bbox_inches='tight')

# %%
# plot 6

v_ext = 0.25
v_dip = -0.5

colors = ['b','g','r','black','grey'] #sns.color_palette()
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,5), sharex=True);

ax1.set_xlim([-1.1,1.1]);
ax1.set_title('Total Gate Voltage')
ax1.set_xlabel('Applied V_gate (V)')
ax1.set_ylabel('Effective Gate Voltage')
ax1.plot(V_bg_up, [0]*1000, '--', color='grey', label='Dirac point')

ax2.set_title('Conductance vs Applied Gate Voltage')
ax2.set_xlabel('Applied V_gate (V)')
ax2.set_ylabel('Conductance')


# next two lines = just applied gate
ax1.plot(V_bg_up, V_bg_up, color=colors[0], alpha=0.25, label='applied backgate');
#ax2.plot(V_bg_up, [conductance(v,0, [0],[0]) for v in V_bg_up],color=colors[0], alpha=0.25)

# next two lines = applied gate + extrinsic doping
ax1.plot(V_bg_up, [v_ext]*1000, color=colors[1], alpha=0.5, label='extrinsic doping')
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext],[0]) for v in V_bg_up],color=colors[1], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping
ax1.plot(V_bg_up, [V_dipole(v, True) for v in V_bg_up], color=colors[2], alpha=0.5, label='dipole doping')
ax1.plot(V_bg_up, [V_dipole(v, False) for v in V_bg_up], color=colors[2], alpha=0.5)
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext + v_dip],[0]) for v in V_bg_up],color=colors[2], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping on half chip
ax2.plot(V_bg_up, [conductance(v,0.5, [v_ext + V_dipole(v,True)],[v_ext]) for v in V_bg_up],color=colors[3], label='sweep up')
ax2.plot(V_bg_up, [conductance(v,0.5, [v_ext + V_dipole(v,False)],[v_ext]) for v in V_bg_up],color=colors[4], label='sweep down')

ax2.legend(loc=1);
ax1.legend(loc=2);

plt.savefig('Fig2-2.png', dpi=200, transparent=True, bbox_inches='tight')

# %%
# plot 5

v_ext = 0.25
v_dip = -0.5

colors = ['b','g','r','black'] #sns.color_palette()
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,5), sharex=True);

ax1.set_xlim([-1.1,1.1]);
ax1.set_title('Total Gate Voltage')
ax1.set_xlabel('Applied V_gate (V)')
ax1.set_ylabel('Effective Gate Voltage')
ax1.plot(V_bg_up, [0]*1000, '--', color='grey', label='Dirac point')

ax2.set_title('Conductance vs Applied Gate Voltage')
ax2.set_xlabel('Applied V_gate (V)')
ax2.set_ylabel('Conductance')
ax2.set_ylim([0,1400]);


# next two lines = just applied gate
ax1.plot(V_bg_up, V_bg_up, color=colors[0], alpha=0.25, label='applied backgate');
#ax2.plot(V_bg_up, [conductance(v,0, [0],[0]) for v in V_bg_up],color=colors[0], alpha=0.25)

# next two lines = applied gate + extrinsic doping
ax1.plot(V_bg_up, [v_ext]*1000, color=colors[1], alpha=0.5, label='extrinsic doping')
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext],[0]) for v in V_bg_up],color=colors[1], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping
ax1.plot(V_bg_up, [v_dip]*1000, color=colors[2], alpha=0.5, label='dipole doping')
#ax2.plot(V_bg_up, [conductance(v,0, [v_ext + v_dip],[0]) for v in V_bg_up],color=colors[2], alpha=0.5)

# next two lines = applied gate + extrinsic doping + dipole doping on half chip
ax2.plot(V_bg_up, [conductance(v,0.5, [v_ext + v_dip],[v_ext]) for v in V_bg_up],color=colors[3], label='sweep up')

ax2.legend(loc=1);
ax1.legend(loc=2);

plt.savefig('Fig2-1.png', dpi=200, transparent=True, bbox_inches='tight')
